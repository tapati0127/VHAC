# %%
# !git clone https://github.com/tapati0127/VHAC.git
# Out:
# Cloning into 'VHAC'...
# remote: Enumerating objects: 58, done.
# remote: Counting objects: 100% (58/58), done.
# remote: Compressing objects: 100% (37/37), done.
# remote: Total 58 (delta 17), reused 58 (delta 17), pack-reused 0
# Receiving objects: 100% (58/58), 47.19 KiB | 7.86 MiB/s, done.
# Resolving deltas: 100% (17/17), done.

# %%
# %cd VHAC
# Out:
# /content/VHAC

# %%
# !pip install gdown

# %%
# !gdown https://drive.google.com/drive/folders/1-UMvWEl7dLY6iv9IiKdaJAow6WPB8Jeh?usp=sharing --folder
# Out:
# Retrieving folder list
# Processing file 1eVfgFsxvJxnLqe8jBIuZxTtzEqEojsLj data_private_question.csv
# Processing file 11ZtEqxF2pPC4Z46c21qkJr6iXO5Qb4we data_public_question.csv
# Processing file 1BzzTVQl1BW9Tzealiq1GOTN6kqM_9Enz documents.jsonl
# Retrieving folder list completed
# Building directory structure
# Building directory structure completed
# Downloading...
# From: https://drive.google.com/uc?id=1eVfgFsxvJxnLqe8jBIuZxTtzEqEojsLj
# To: /content/VHAC/data/data_private_question.csv
# 100% 16.5k/16.5k [00:00<00:00, 50.0MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=11ZtEqxF2pPC4Z46c21qkJr6iXO5Qb4we
# To: /content/VHAC/data/data_public_question.csv
# 100% 24.0k/24.0k [00:00<00:00, 74.5MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1BzzTVQl1BW9Tzealiq1GOTN6kqM_9Enz
# To: /content/VHAC/data/documents.jsonl
# 100% 59.8M/59.8M [00:00<00:00, 197MB/s]
# Download completed

# %%
# !gdown https://drive.google.com/drive/folders/11cmhjBNk5e5zYmKgcbCTbdg1WIOpBQc8?usp=sharing --folder
# Out:
# Retrieving folder list
# Retrieving folder 1-3ssLdVLlV3AQ1AXZfS95TJOpOZqL4PA biencoder
# Processing file 123w9eGWSgoMJP-vapNEi8ytosJ0bVdod config.json
# Processing file 11wV2PSIzqL7BcY1Z74vFo99TNfJmTiXr pytorch_model.bin
# Processing file 122F882PuJfcnr_v-llFvfAdhGjWPpFRI sentencepiece.bpe.model
# Processing file 1_acMn-qElgpN0aJwShBBqySKyylWLFo0 training_params.txt
# Processing file 128Nc8foUstHGwcZhp0B607S_aQC4t-Gc cand_encode.t7
# Retrieving folder 1bDVMpx2-E0QhJt9X2rt_mSADLNFxmkjA crossencoder
# Retrieving folder 12_5Z8yl6VWZuktAw7JRLtiMEXU2X-adN cross
# Processing file 14Jd2kgeUAvSxkNugtLb9tQWlXCQ7SUvs config.json
# Processing file 14Fv2WPlL3feOaxWnUHe8_33dNf3uxbWM pytorch_model.bin
# Processing file 14H8jGXY_294HaM_IswcO-PynHX3vz0B_ sentencepiece.bpe.model
# Processing file 12_XLbE1tZY9UnbrwRgHX9eLDBfbGePja training_params.txt
# Retrieving folder list completed
# Building directory structure
# Building directory structure completed
# Downloading...
# ...

# %%
# !pip install --upgrade transformers scipy pytorch_transformers faiss-cpu bitsandbytes
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 24.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.4/176.4 kB 21.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.6/17.6 MB 72.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.6/92.6 MB 9.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.0/302.0 kB 33.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 80.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 81.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.8/135.8 kB 16.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 60.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 880.6/880.6 kB 46.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 28.9 MB/s eta 0:00:00
# ...

# %%
# !python run_retrieval_and_answer_t5.py
# Out:
# ...
# Size of Tokenizer: 250005
# ...
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# ****************************************************************************************************
# 0
# Nhật Bản đã tổ chức mấy kì Thế Vận hội mùa hè?
# ******************************
# Thế vận hội Mùa hè 2020
#  Tóm tắt
# ...
